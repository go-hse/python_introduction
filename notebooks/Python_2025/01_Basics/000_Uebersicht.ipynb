# %% [markdown]
# # Übersicht
#
# - [Einführung](http://localhost:8888/notebooks/001_Intro.ipynb)
# - [Datentypen](http://localhost:8888/notebooks/002_Datentypen.ipynb)
# - [Variablen](http://localhost:8888/notebooks/003_Variablen.ipynb)
# - [Arbeiten mit Variablen](http://localhost:8888/notebooks/004_Variablen_II.ipynb)
# - [Übungen zu Variablen](http://localhost:8888/notebooks/005_Variablen_Uebungen.ipynb)
# - [Kontrollstrukturen](http://localhost:8888/notebooks/006_Kontrollstrukturen.ipynb)
# - [Übungen mit Verzweigungen](http://localhost:8888/notebooks/007_Kontrollstrukturen_if_Uebungen.ipynb)
# - [Ein- und Ausgabe](http://localhost:8888/notebooks/008_Print_Input.ipynb)
# - [Formatierte Ausgabe](http://localhost:8888/notebooks/009_Formated_Print.ipynb)
# - [Übungen zu For-Schleifen mit Listen](http://localhost:8888/notebooks/010_For_List_Uebungen.ipynb)
# - [Übungen zu For-Schleifen mit Bereichen (range)](http://localhost:8888/notebooks/011_For_Range_Uebungen.ipynb)
# - [Übungen zu While-Schleifen](http://localhost:8888/notebooks/012_While_Uebungen.ipynb)
# - [Listen](http://localhost:8888/notebooks/020_Listen.ipynb)
# - [Liste-Elemente (Slicing)](http://localhost:8888/notebooks/021_Listen_Slicing.ipynb)
# - [Dictionaries](http://localhost:8888/notebooks/022_Dictionaries.ipynb)
# - [Übungen zu Listen und Dictionaries](http://localhost:8888/notebooks/023_List_Dicts_Uebungen.ipynb)
# - [Funktionen](http://localhost:8888/notebooks/024_Funktionen.ipynb)
# - [Übungen zu Funktionen](http://localhost:8888/notebooks/025_Funktionen_Uebungen.ipynb)
# - [Module](http://localhost:8888/notebooks/030_Module.ipynb)
# - [Pip](http://localhost:8888/notebooks/031_Pip.ipynb)
